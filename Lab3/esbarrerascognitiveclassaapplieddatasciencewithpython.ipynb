# %% [markdown]
# **Link de LinkedIn:** www.linkedin.com/in/esteban-barrera-440ba7273

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/content/Linkedin.png')
plt.imshow(img)
plt.axis('off')
plt.show()
